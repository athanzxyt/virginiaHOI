# %% [markdown]
# # Train/Test Split Steps

# %%
## Import Libraries
import pandas as pd
import numpy as np
from scipy.io.arff import loadarff

from sklearn.model_selection import train_test_split

# %%
## Read in Subsets
names = ['subset1-corr.csv', 
         'subset2-infogain.csv',
         'subset3-oneR.csv',
         'subset4-wrapper.csv',
         'subset5-intuition.csv']

dfs = [pd.read_csv(name) for name in names]
# Out:
#       'Material Deprivation'  Affordability  'Population Churning'  \
# 0                   0.000000       0.043043               0.468193
# 1                   0.133458       0.641642               0.022901
# 2                   0.343863       0.627628               0.513995
# 3                   0.228861       0.021021               0.444020
# 4                   0.184284       0.662663               0.427481
# ...                      ...            ...                    ...
# 1850                0.692808       0.681682               0.891858
# 1851                0.735580       0.725726               0.930025
# 1852                0.675777       0.655656               0.946565
# 1853                0.670792       0.629630               0.898219
# 1854                0.697936       0.304304               0.039440
#
#       'Community Environment Profile'  'Income Inequality'  \
# 0                            0.540012             0.034818
# ...

# %%
## Train/Test Splits
for i in range(len(dfs)):
    train, test = train_test_split(dfs[i], 
                                test_size=0.2, 
                                random_state=2023, 
                                stratify=df[['Health Opportunity Index']])
    train.to_csv(f'split/train{i}.csv')
    test.to_csv(f'split/test{i}.csv')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7a3c50ae-2818-43ba-b0aa-358dc90fd9e6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
